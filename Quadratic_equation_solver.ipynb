# %% [markdown]
# # Quadratic Equation

# %% [markdown]
# This is an open-research conducted on Mathematics, which is key features and core study in Engineering. All material used during research are free of cost and open-source softwares, such as Jupyter Notebook, Pandas, Numpy, Seaborn, Matplotlib, Math Python in-built libraries and Previous publish journals (most of them are professional industrial or univeristy websites)

# %% [markdown]
# #### CHRISLER NUNES

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# #### Import Libraries

# %%
import sympy as sp
import math
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import warnings
warnings.filterwarnings('ignore', category=UserWarning, append=True)

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# #### Quadratic Formula

# %%
a, b, c = sp.symbols("a,b,c")
solution1_positive = (-b+(sp.sqrt(b**2-4*a*c)))/(2*a)
solution2_negative = (-b-(sp.sqrt(b**2-4*a*c)))/(2*a)

# %%
solution1_positive
# Out:
# (-b + sqrt(-4*a*c + b**2))/(2*a)

# %%
solution2_negative
# Out:
# (-b - sqrt(-4*a*c + b**2))/(2*a)

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# #### Quadratic equation solved using sympsy

# %% [markdown]
# This quadratic equation solver that will solve a second-order polynomial equation such as ax2 + bx + c = 0 for x, where a ≠ 0, using the quadratic formula.
#
# The calculator solution will show work using the quadratic formula to solve the entered equation for real and complex roots. Calculator determines whether the discriminant (b2−4ac) is less than, greater than or equal to 0.

# %% [markdown]
#  When (b^2 − 4ac) = 0 there is one real root.

# %%
one_real_root = sp.Eq((b**2)-4*a*c, 0)
one_real_root
# Out:
# Eq(-4*a*c + b**2, 0)

# %% [markdown]
#  When (b^2 − 4ac)>0, there are two real roots.

# %%
b**2-4*a*c > 0
# Out:
# -4*a*c + b**2 > 0

# %% [markdown]
# When(b^2−4ac)<0, there are two complex roots

# %%
b**2-4*a*c < 0
# Out:
# -4*a*c + b**2 < 0

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# The above is used to solve quadratic equations where a ≠ 0 (polynomials with an order of 2)

# %%
a,b,c,x = sp.symbols("a,b,c,x")
f = sp.Eq(a*x**2+b*x+c, 0)
f
# Out:
# Eq(a*x**2 + b*x + c, 0)

# %% [markdown]
# The Discriminant are ± √((b^2) − 4ac)
#
# 1. Positive, there are 2 real solutions
#
# 2. Zero, there is one real solution
#
# 3. Negative, there are 2 complex solutions

# %% [markdown]
# --------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Case 1 (No real roots)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# %%time
def quadratic(a,b,c): 
#Quadratic formula for discriminant and zero points
    discriminant = (b**2) - (4*a*c) 
    dis_negative = (-b-(sp.sqrt(b**2-4*a*c)))/(2*a)
    dis_positive = (-b+(sp.sqrt(b**2-4*a*c)))/(2*a)
 #Control flow statement for finding root or no-root   
    if discriminant < 0: 
        print("\nThere is no real root")
    elif discriminant == 0:
        print("\nThere only one root")
    elif discriminant > 0:
        print("\nThere are two real roots")
#Control flow statement for finding parabola convex or concave 
    if a>0:
        print("\nParabola is convex")
    else:
        print("\nParabola is concave")
        
#Calculate parabola extreme coordinates      
#X-axis coordinate vertex
    x_coord_vertex = -b/(2*a)
#Y-axis coordinate vertex
    ax2 = (a*(-b/(2*a))**2)
    bx = (b*(-b/(2*a)))
    y_coord_vertex = ax2 + bx + c
#Sum root
    sum_root = (-b/a)
#Product root
    product_of_root = (c/a)

    return discriminant, dis_negative, dis_positive, x_coord_vertex, y_coord_vertex, sum_root, product_of_root

#Coefficients
print("INPUT:")
print("\nCoefficients")
a = float(input('Input coefficient a: '))  
b = float(input('Input coefficient b: '))  
c = float(input('Input coefficient c: ')) 
result = quadratic(a,b,c)

solution = [result]
discriminant_index = solution[0][0]
real_solution_index = solution[0][1]
complex_solution_index = solution[0][2]
x_coord_index = solution[0][3]
y_coord_index = solution[0][4]
sum_root = solution[0][5]
product_of_root = solution[0][6]
    
print("\nOUTPUT:")
print(f"Discriminant: {math.floor(discriminant_index)}")
print("\nPositive discriminant solution")
print(f"roots: {real_solution_index}")
print("\nNegative discriminant solution")
print(f"roots: {complex_solution_index}")
print(f"\nx-coordinate vertex: {x_coord_index}, y-coordinate vertex: {y_coord_index}")
print(f"\nSum root: {sum_root}")
print(f"\nProduct of root: {product_of_root}")
# Out:
# INPUT:
#
# Coefficients
# Input coefficient a:  12
# Input coefficient b:  10
# Input coefficient c:  9
# There is no real root
#
# Parabola is convex
#
# OUTPUT:
# Discriminant: -332
#
# Positive discriminant solution
# roots: -0.416666666666667 - 0.759202798262025*I
#
# Negative discriminant solution
# roots: -0.416666666666667 + 0.759202798262025*I
#
# x-coordinate vertex: -0.4166666666666667, y-coordinate vertex: 6.916666666666666
#
# Sum root: -0.8333333333333334
#
# Product of root: 0.75
# CPU times: user 105 ms, sys: 51.7 ms, total: 157 ms
# Wall time: 12.1 s

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# #### Graph plotting

# %%
print(f"a:{a}, b:{b}, c:{c}")
# Out:
# a:12.0, b:10.0, c:9.0

# %%
y = a*x**2 + b*x + c
plt.style.use("ggplot")
fig, axis = plt.subplots(figsize=(15,10))
x = np.linspace(-5, 5, 100)
axis.plot(x, y)

axis.set_title("Quadratic Equations")
plt.xlabel('x - axis')
plt.ylabel('y - axis')
plt.axvline(x = 0, color = 'black')
plt.axhline(y = 0, color = 'black')
plt.show()

# %%
def parabola(x,a,b,c):
    y = a*x**2 + b*x + c
    return y
y_axis_coordinate = y
x_axis_coordinate = x

# %%
y_axis_coordinate
# Out:
# array([259.        , 248.01132537, 237.26752372, 226.76859504,
#        216.51453933, 206.5053566 , 196.74104683, 187.22161004,
#        177.94704622, 168.91735537, 160.1325375 , 151.59259259,
#        143.29752066, 135.2473217 , 127.44199571, 119.8815427 ,
#        112.56596266, 105.49525559,  98.66942149,  92.08846036,
#         85.75237221,  79.66115702,  73.81481481,  68.21334558,
#         62.85674931,  57.74502602,  52.8781757 ,  48.25619835,
#         43.87909397,  39.74686257,  35.85950413,  32.21701867,
#         28.81940618,  25.66666667,  22.75880012,  20.09580655,
#         17.67768595,  15.50443832,  13.57606367,  11.89256198,
#         10.45393327,   9.26017753,   8.31129477,   7.60728497,
#          7.14814815,   6.9338843 ,   6.96449342,   7.23997551,
#          7.76033058,   8.52555862,   9.53565963,  10.79063361,
#         12.29048056,  14.03520049,  16.02479339,  18.25925926,
#         20.7385981 ,  23.46280992,  26.4318947 ,  29.64585246,
#         33.1046832 ,  36.8083869 ,  40.75696358,  44.95041322,
#         49.38873584,  54.07193144,  59.        ,  64.17294154,
#         69.59075605,  75.25344353,  81.16100398,  87.3134374 ,
#         93.7107438 , 100.35292317, 107.23997551, 114.37190083,
#        121.74869911, 129.37037037, 137.2369146 , 145.3483318 ,
#        153.70462198, 162.30578512, 171.15182124, 180.24273033,
#        189.5785124 , 199.15916743, 208.98469544, 219.05509642,
#        229.37037037, 239.93051729, 250.73553719, 261.78543006,
#        273.0801959 , 284.61983471, 296.4043465 , 308.43373125,
#        320.70798898, 333.22711968, 345.99112335, 359.        ])

# %%
x_axis_coordinate
# Out:
# array([-5.        , -4.8989899 , -4.7979798 , -4.6969697 , -4.5959596 ,
#        -4.49494949, -4.39393939, -4.29292929, -4.19191919, -4.09090909,
#        -3.98989899, -3.88888889, -3.78787879, -3.68686869, -3.58585859,
#        -3.48484848, -3.38383838, -3.28282828, -3.18181818, -3.08080808,
#        -2.97979798, -2.87878788, -2.77777778, -2.67676768, -2.57575758,
#        -2.47474747, -2.37373737, -2.27272727, -2.17171717, -2.07070707,
#        -1.96969697, -1.86868687, -1.76767677, -1.66666667, -1.56565657,
#        -1.46464646, -1.36363636, -1.26262626, -1.16161616, -1.06060606,
#        -0.95959596, -0.85858586, -0.75757576, -0.65656566, -0.55555556,
#        -0.45454545, -0.35353535, -0.25252525, -0.15151515, -0.05050505,
#         0.05050505,  0.15151515,  0.25252525,  0.35353535,  0.45454545,
#         0.55555556,  0.65656566,  0.75757576,  0.85858586,  0.95959596,
#         1.06060606,  1.16161616,  1.26262626,  1.36363636,  1.46464646,
#         1.56565657,  1.66666667,  1.76767677,  1.86868687,  1.96969697,
#         2.07070707,  2.17171717,  2.27272727,  2.37373737,  2.47474747,
#         2.57575758,  2.67676768,  2.77777778,  2.87878788,  2.97979798,
#         3.08080808,  3.18181818,  3.28282828,  3.38383838,  3.48484848,
#         3.58585859,  3.68686869,  3.78787879,  3.88888889,  3.98989899,
#         4.09090909,  4.19191919,  4.29292929,  4.39393939,  4.49494949,
#         4.5959596 ,  4.6969697 ,  4.7979798 ,  4.8989899 ,  5.        ])

# %%
dict = {"x-axis":x_axis_coordinate,"y-axis":y_axis_coordinate}
df = pd.DataFrame(dict)
df.to_csv(r"quad_graph_axis.csv", index=False)
df
# Out:
#      x-axis      y-axis
# 0  -5.00000  259.000000
# 1  -4.89899  248.011325
# 2  -4.79798  237.267524
# 3  -4.69697  226.768595
# 4  -4.59596  216.514539
# ..      ...         ...
# 95  4.59596  308.433731
# 96  4.69697  320.707989
# 97  4.79798  333.227120
# 98  4.89899  345.991123
# 99  5.00000  359.000000
#
# [100 rows x 2 columns]

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# #### Excel graph plot

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Case 2 (Two real roots)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# %%time
def quadratic(a,b,c): 
#Quadratic formula for discriminant and zero points
    discriminant = (b**2) - (4*a*c) 
    dis_negative = (-b-(sp.sqrt(b**2-4*a*c)))/(2*a)
    dis_positive = (-b+(sp.sqrt(b**2-4*a*c)))/(2*a)
 #Control flow statement for finding root or no-root   
    if discriminant < 0: 
        print("\nThere is no real root")
    elif discriminant == 0:
        print("\nThere only one root")
    elif discriminant > 0:
        print("\nThere are two real roots")
#Control flow statement for finding parabola convex or concave 
    if a>0:
        print("\nParabola is convex")
    else:
        print("\nParabola is concave")
        
#Calculate parabola extreme coordinates      
#X-axis coordinate vertex
    x_coord_vertex = -b/(2*a)
#Y-axis coordinate vertex
    ax2 = (a*(-b/(2*a))**2)
    bx = (b*(-b/(2*a)))
    y_coord_vertex = ax2 + bx + c
#Sum root
    sum_root = (-b/a)
#Product root
    product_of_root = (c/a)

    return discriminant, dis_negative, dis_positive, x_coord_vertex, y_coord_vertex, sum_root, product_of_root

#Coefficients
print("INPUT:")
print("\nCoefficients")
a = float(input('Input coefficient a: '))  
b = float(input('Input coefficient b: '))  
c = float(input('Input coefficient c: ')) 
result = quadratic(a,b,c)

solution = [result]
discriminant_index = solution[0][0]
real_solution_index = solution[0][1]
complex_solution_index = solution[0][2]
x_coord_index = solution[0][3]
y_coord_index = solution[0][4]
sum_root = solution[0][5]
product_of_root = solution[0][6]
    
print("\nOUTPUT:")
print(f"Discriminant: {math.floor(discriminant_index)}")
print("\nPositive discriminant solution")
print(f"roots: {real_solution_index}")
print("\nNegative discriminant solution")
print(f"roots: {complex_solution_index}")
print(f"\nx-coordinate vertex: {x_coord_index}, y-coordinate vertex: {y_coord_index}")
print(f"\nSum root: {sum_root}")
print(f"\nProduct of root: {product_of_root}")
# Out:
# INPUT:
#
# Coefficients
# Input coefficient a:  12

# %% [markdown]
# #### Graph plotting

# %%
print(f"a:{a}, b:{b}, c:{c}")

# %%
y = a*x**2 + b*x + c
plt.style.use("ggplot")
fig, axis = plt.subplots(figsize=(15,10))
x = np.linspace(-5, 5, 100)
axis.plot(x, y)

axis.set_title("Quadratic Equations")
plt.xlabel('x - axis')
plt.ylabel('y - axis')
plt.axvline(x = 0, color = 'black')
plt.axhline(y = 0, color = 'black')
plt.show()

# %%
def parabola(x,a,b,c):
    y = a*x**2 + b*x + c
    return y
y_axis_coordinate = y
x_axis_coordinate = x

# %%
y_axis_coordinate

# %%
x_axis_coordinate

# %%
dict = {"x-axis":x_axis_coordinate,"y-axis":y_axis_coordinate}
df = pd.DataFrame(dict)
df.to_csv(r"quad_graph_axis2.csv", index=False)
df

# %% [markdown]
# #### Excel Graph plotting

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Case 3 (One real root)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# %%time
def quadratic(a,b,c): 
#Quadratic formula for discriminant and zero points
    discriminant = (b**2) - (4*a*c) 
    dis_negative = (-b-(sp.sqrt(b**2-4*a*c)))/(2*a)
    dis_positive = (-b+(sp.sqrt(b**2-4*a*c)))/(2*a)
 #Control flow statement for finding root or no-root   
    if discriminant < 0: 
        print("\nThere is no real root")
    elif discriminant == 0:
        print("\nThere only one root")
    elif discriminant > 0:
        print("\nThere are two real roots")
#Control flow statement for finding parabola convex or concave 
    if a>0:
        print("\nParabola is convex")
    else:
        print("\nParabola is concave")
        
#Calculate parabola extreme coordinates      
#X-axis coordinate vertex
    x_coord_vertex = -b/(2*a)
#Y-axis coordinate vertex
    ax2 = (a*(-b/(2*a))**2)
    bx = (b*(-b/(2*a)))
    y_coord_vertex = ax2 + bx + c
#Sum root
    sum_root = (-b/a)
#Product root
    product_of_root = (c/a)

    return discriminant, dis_negative, dis_positive, x_coord_vertex, y_coord_vertex, sum_root, product_of_root

#Coefficients
print("INPUT:")
print("\nCoefficients")
a = float(input('Input coefficient a: '))  
b = float(input('Input coefficient b: '))  
c = float(input('Input coefficient c: ')) 
result = quadratic(a,b,c)

solution = [result]
discriminant_index = solution[0][0]
real_solution_index = solution[0][1]
complex_solution_index = solution[0][2]
x_coord_index = solution[0][3]
y_coord_index = solution[0][4]
sum_root = solution[0][5]
product_of_root = solution[0][6]
    
print("\nOUTPUT:")
print(f"Discriminant: {math.floor(discriminant_index)}")
print("\nPositive discriminant solution")
print(f"roots: {real_solution_index}")
print("\nNegative discriminant solution")
print(f"roots: {complex_solution_index}")
print(f"\nx-coordinate vertex: {x_coord_index}, y-coordinate vertex: {y_coord_index}")
print(f"\nSum root: {sum_root}")
print(f"\nProduct of root: {product_of_root}")

# %% [markdown]
# #### Graph plotting

# %%
print(f"a:{a}, b:{b}, c:{c}")

# %%
y = a*x**2 + b*x + c
plt.style.use("ggplot")
fig, axis = plt.subplots(figsize=(15,10))
x = np.linspace(-5, 5, 100)
axis.plot(x, y)

axis.set_title("Quadratic Equations")
plt.xlabel('x - axis')
plt.ylabel('y - axis')
plt.axvline(x = 0, color = 'black')
plt.axhline(y = 0, color = 'black')
plt.show()

# %%
def parabola(x,a,b,c):
    y = a*x**2 + b*x + c
    return y
y_axis_coordinate = y
x_axis_coordinate = x

# %%
y_axis_coordinate

# %%
x_axis_coordinate

# %% [markdown]
# #### Graph plotting

# %%
dict = {"x-axis":x_axis_coordinate,"y-axis":y_axis_coordinate}
df = pd.DataFrame(dict)
df.to_csv(r"quad_graph_axis3.csv", index=False)
df

# %% [markdown]
# #### Excel Graph plotting

# %% [markdown]
# ![image.png](attachment:image.png)
